# %% [markdown]
# ### run to calculate mean and standard deviation

# %%
values = [1.000, 1.000, 0.800, 0.667, 0.800, 0.667, 0.571]

import numpy as np

mean = np.mean(values)
std_dev = np.std(values)
print(f"Mean: {mean}, Standard Deviation: {std_dev}")
# Out:
# Mean: 0.7864285714285713, Standard Deviation: 0.1542399402997598
